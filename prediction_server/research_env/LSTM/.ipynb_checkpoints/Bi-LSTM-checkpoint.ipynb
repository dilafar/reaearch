# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("./cpu_usage.csv", parse_dates=[0])
dataset.head(20)
# Out:
#              Timestamp  CPU cores  CPU capacity provisioned [MHZ]  \
# 0  2015-01-04 00:00:00          2                               0
# 1  2015-01-04 00:05:00          2                               0
# 2  2015-01-04 00:10:00          2                               0
# 3  2015-01-04 00:15:00          2                               0
# 4  2015-01-04 00:20:00          2                               0
# 5  2015-01-04 00:25:00          2                               0
# 6  2015-01-04 00:30:00          2                               0
# 7  2015-01-04 00:35:00          2                               0
# 8  2015-01-04 00:40:00          2                               0
# 9  2015-01-04 00:45:00          2                               0
# 10 2015-01-04 00:50:00          2                               0
# 11 2015-01-04 00:55:00          2                               0
# 12 2015-01-04 01:00:00          2                               0
# 13 2015-01-04 01:05:00          2                               0
# 14 2015-01-04 01:10:00          2                               0
# 15 2015-01-04 01:15:00          2                               0
# 16 2015-01-04 01:20:00          2                               0
# 17 2015-01-04 01:25:00          2                               0
# 18 2015-01-04 01:30:00          2                               0
# 19 2015-01-04 01:35:00          2                               0
#
#     CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0               156           3.40                           4194304
# 1               150           3.27                           4194304
# 2               158           3.46                           4194304
# 3               156           3.40                           4194304
# 4               159           3.47                           4194304
# 5               152           3.31                           4194304
# 6               149           3.25                           4194304
# 7               160           3.50                           4194304
# 8               156           3.40                           4194304
# 9               148           3.23                           4194304
# 10              169           3.69                           4194304
# 11              148           3.23                           4194304
# 12              150           3.28                           4194304
# 13              167           3.64                           4194304
# 14              148           3.23                           4194304
# 15              150           3.28                           4194304
# 16              157           3.42                           4194304
# 17              136           2.97                           4194304
# 18              141           3.08                           4194304
# 19              133           2.92                           4194304
#
#     Memory usage [KB]  Memory usage [%]  Disk read throughput [KB/s]  \
# 0             1050673             25.05                            0
# 1             1095552             26.12                            0
# 2             1025507             24.45                            0
# 3              992372             23.66                            0
# 4             1129107             26.92                            0
# 5             1092616             26.05                            0
# 6              958398             22.85                            0
# 7             1187827             28.32                            0
# 8             1101005             26.25                            0
# 9             1115265             26.59                            0
# 10            1241095             29.59                            0
# 11            1182374             28.19                            0
# 12            1053609             25.12                            0
# 13             941621             22.45                            0
# 14            1011666             24.12                            0
# 15             964270             22.99                            0
# 16             983564             23.45                            0
# 17             891290             21.25                            0
# 18             885837             21.12                            0
# 19             939105             22.39                            0
#
#     Disk write throughput [KB/s]  Disk size [GB]  \
# 0                             14              54
# 1                             17              54
# 2                             15              54
# 3                             16              54
# 4                             15              54
# 5                             15              54
# 6                             13              54
# 7                             72              54
# 8                             14              54
# 9                             15              54
# 10                            15              54
# 11                            16              54
# 12                            15              54
# 13                            16              54
# 14                            14              54
# 15                            15              54
# 16                            14              54
# 17                            16              54
# 18                            14              54
# 19                            15              54
#
#     Network received throughput [KB/s]  Network transmitted throughput [KB/s]
# 0                                   12                                     45
# 1                                    2                                     13
# 2                                   12                                     45
# 3                                    3                                     12
# 4                                   13                                     46
# 5                                    2                                     11
# 6                                    2                                     11
# 7                                    2                                     53
# 8                                   12                                     45
# 9                                    2                                     11
# 10                                  12                                     45
# 11                                   2                                     11
# 12                                   2                                     11
# 13                                 164                                     20
# 14                                   2                                     11
# 15                                   2                                     11
# 16                                  12                                     45
# 17                                   2                                     11
# 18                                  12                                     45
# 19                                   2                                     11

# %%
dataset = dataset.set_index('Timestamp').asfreq(freq='5min')

dataset.drop(columns=[
    'CPU cores',
    'CPU capacity provisioned [MHZ]',
    'CPU usage [MHZ]',
    'Memory capacity provisioned [KB]',
    'Memory usage [KB]',
    'Memory usage [%]',
    'Disk read throughput [KB/s]',
    'Disk write throughput [KB/s]',
    'Disk size [GB]',
    'Network received throughput [KB/s]',
    'Network transmitted throughput [KB/s]'
] , inplace=True)

# %%
dataset.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
dataset.columns[0]
# Out:
# 'CPU usage [%]'

# %%
train = dataset.iloc[:1620]
test = dataset.iloc[1620:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler_train = scaler.fit(train)
scaler_train = scaler.transform(train)
scaler_test = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
n_input =12
n_features = 1

generator = TimeseriesGenerator(scaler_train,scaler_train,length=n_input,batch_size=1)

# %%
len(generator)
# Out:
# 1608

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM , Conv1D ,MaxPooling1D
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.optimizers import Adam
#from keras.optimizers import clipnorm
from keras import regularizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau

# %%
from keras.layers import Input, Dense, LSTM, Conv1D, Dropout, Bidirectional, Multiply
from keras.models import Model
# from attention_utils import get_activations
from keras.models import *
from sklearn.model_selection import train_test_split

# %%
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True, activation='relu'), input_shape=(n_input, n_features)))
model.add(Bidirectional(LSTM(64, return_sequences=False, activation='relu')))
#model.add(Dense(units=16))
#model.add(Dense(units=2))
model.add(Dense(units=1))
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(factor=0.5, patience=5, min_lr=1e-6)

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_12 (Bidirect  (None, 12, 128)           33792
#  ional)
#
#  bidirectional_13 (Bidirect  (None, 128)               98816
#  ional)
#
#  dense_21 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 132737 (518.50 KB)
# Trainable params: 132737 (518.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(generator,epochs=100,batch_size=32, callbacks=[early_stopping,lr_scheduler])
# Out:
# Epoch 1/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 0.0011WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 29s 14ms/step - loss: 0.0011 - lr: 0.0010
# Epoch 2/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 0.0011WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 21s 13ms/step - loss: 0.0011 - lr: 0.0010
# Epoch 3/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 21s 13ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 4/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 23s 15ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 5/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 21s 13ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 6/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.7026e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 22s 14ms/step - loss: 9.6867e-04 - lr: 0.0010
# Epoch 7/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 21s 13ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 8/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.7836e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 21s 13ms/step - loss: 9.7655e-04 - lr: 0.0010
# Epoch 9/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.8655e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 23s 14ms/step - loss: 9.8473e-04 - lr: 0.0010
# Epoch 10/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.5770e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 22s 14ms/step - loss: 9.5723e-04 - lr: 0.0010
# Epoch 11/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.6033e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 21s 13ms/step - loss: 9.5856e-04 - lr: 0.0010
# Epoch 12/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.6047e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 9.6047e-04 - lr: 0.0010
# Epoch 13/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.3643e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 23s 14ms/step - loss: 9.3503e-04 - lr: 0.0010
# Epoch 14/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.2647e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 23s 14ms/step - loss: 9.2475e-04 - lr: 0.0010
# Epoch 15/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.0201e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 22s 14ms/step - loss: 9.0094e-04 - lr: 0.0010
# Epoch 16/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.5345e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 22s 13ms/step - loss: 9.5228e-04 - lr: 0.0010
# Epoch 17/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.4027e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 22s 14ms/step - loss: 9.3856e-04 - lr: 0.0010
# Epoch 18/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.3596e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 22s 14ms/step - loss: 9.3596e-04 - lr: 0.0010
# Epoch 19/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.2531e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 23s 14ms/step - loss: 9.2531e-04 - lr: 0.0010
# Epoch 20/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.1110e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 22s 14ms/step - loss: 9.1110e-04 - lr: 0.0010
# Epoch 21/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.4324e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 29s 18ms/step - loss: 9.4324e-04 - lr: 0.0010
# Epoch 22/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.0361e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 31s 19ms/step - loss: 9.0307e-04 - lr: 0.0010
# Epoch 23/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.4004e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 9.4004e-04 - lr: 0.0010
# Epoch 24/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.1401e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 24s 15ms/step - loss: 9.1287e-04 - lr: 0.0010
# Epoch 25/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.0077e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 8.9919e-04 - lr: 0.0010
# Epoch 26/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.1383e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 9.1275e-04 - lr: 0.0010
# Epoch 27/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.9250e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 8.9162e-04 - lr: 0.0010
# Epoch 28/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.7927e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 8.7927e-04 - lr: 0.0010
# Epoch 29/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.7939e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 30s 19ms/step - loss: 8.7939e-04 - lr: 0.0010
# Epoch 30/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.7654e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 33s 21ms/step - loss: 8.7654e-04 - lr: 0.0010
# Epoch 31/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.4340e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 31s 19ms/step - loss: 8.4236e-04 - lr: 0.0010
# Epoch 32/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.3051e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 49s 31ms/step - loss: 8.2999e-04 - lr: 0.0010
# Epoch 33/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.5845e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 37s 23ms/step - loss: 8.5793e-04 - lr: 0.0010
# Epoch 34/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.2874e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 8.2791e-04 - lr: 0.0010
# Epoch 35/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.6620e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 15ms/step - loss: 8.6566e-04 - lr: 0.0010
# Epoch 36/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 7.8657e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 27s 17ms/step - loss: 7.8573e-04 - lr: 0.0010
# Epoch 37/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.1455e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 8.1435e-04 - lr: 0.0010
# Epoch 38/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 7.9425e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 7.9278e-04 - lr: 0.0010
# Epoch 39/100
# 1608/1608 [==============================] - ETA: 0s - loss: 7.6492e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 7.6492e-04 - lr: 0.0010
# Epoch 40/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.0759e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 8.0662e-04 - lr: 0.0010
# Epoch 41/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 7.4154e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 28s 17ms/step - loss: 7.4062e-04 - lr: 0.0010
# Epoch 42/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 6.8842e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 28s 17ms/step - loss: 6.8804e-04 - lr: 0.0010
# Epoch 43/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 7.0376e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 27s 17ms/step - loss: 7.0293e-04 - lr: 0.0010
# Epoch 44/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 6.9501e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 29s 18ms/step - loss: 6.9408e-04 - lr: 0.0010
# Epoch 45/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 5.6447e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 31s 19ms/step - loss: 5.6377e-04 - lr: 0.0010
# Epoch 46/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 6.0211e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 30s 19ms/step - loss: 6.0137e-04 - lr: 0.0010
# Epoch 47/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.5936e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 32s 20ms/step - loss: 8.5936e-04 - lr: 0.0010
# Epoch 48/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 5.1187e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 31s 19ms/step - loss: 5.1166e-04 - lr: 0.0010
# Epoch 49/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 4.0224e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 28s 17ms/step - loss: 4.0302e-04 - lr: 0.0010
# Epoch 50/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 3.5715e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.5652e-04 - lr: 0.0010
# Epoch 51/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 3.5315e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.5619e-04 - lr: 0.0010
# Epoch 52/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 4.7439e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 4.7389e-04 - lr: 0.0010
# Epoch 53/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 6.0847e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 6.0814e-04 - lr: 0.0010
# Epoch 54/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 55/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.9471e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 8.9392e-04 - lr: 0.0010
# Epoch 56/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 6.0633e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 15ms/step - loss: 6.0598e-04 - lr: 0.0010
# Epoch 57/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.6114e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 9.5996e-04 - lr: 0.0010
# Epoch 58/100
# 1608/1608 [==============================] - ETA: 0s - loss: 4.6940e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 4.6940e-04 - lr: 0.0010
# Epoch 59/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 7.0208e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 7.0164e-04 - lr: 0.0010
# Epoch 60/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 4.3986e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 15ms/step - loss: 4.3944e-04 - lr: 0.0010
# Epoch 61/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.3899e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 3.3899e-04 - lr: 0.0010
# Epoch 62/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 3.0800e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 3.0781e-04 - lr: 0.0010
# Epoch 63/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 3.8656e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.8632e-04 - lr: 0.0010
# Epoch 64/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.9844e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.9844e-04 - lr: 0.0010
# Epoch 65/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 3.4800e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 27s 17ms/step - loss: 3.4779e-04 - lr: 0.0010
# Epoch 66/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.3544e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 24s 15ms/step - loss: 3.3544e-04 - lr: 0.0010
# Epoch 67/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 4.2451e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 28s 17ms/step - loss: 4.2410e-04 - lr: 0.0010
# Epoch 68/100
# 1608/1608 [==============================] - ETA: 0s - loss: 4.1647e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 15ms/step - loss: 4.1647e-04 - lr: 0.0010
# Epoch 69/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.0151e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 8.9983e-04 - lr: 0.0010
# Epoch 70/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.2341e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 8.2292e-04 - lr: 0.0010
# Epoch 71/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 3.9793e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.9782e-04 - lr: 0.0010
# Epoch 72/100
# 1608/1608 [==============================] - ETA: 0s - loss: 4.7072e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 28s 17ms/step - loss: 4.7072e-04 - lr: 0.0010
# Epoch 73/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 2.6891e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 27s 17ms/step - loss: 2.6889e-04 - lr: 0.0010
# Epoch 74/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.4563e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 29s 18ms/step - loss: 3.4563e-04 - lr: 0.0010
# Epoch 75/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 4.1558e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 4.1532e-04 - lr: 0.0010
# Epoch 76/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 3.2494e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.2495e-04 - lr: 0.0010
# Epoch 77/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 3.0117e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.0065e-04 - lr: 0.0010
# Epoch 78/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 6.1157e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 30s 19ms/step - loss: 6.1047e-04 - lr: 0.0010
# Epoch 79/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.4753e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 30s 19ms/step - loss: 3.4753e-04 - lr: 0.0010
# Epoch 80/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.5836e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 32s 20ms/step - loss: 3.5836e-04 - lr: 0.0010
# Epoch 81/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 3.4718e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 28s 17ms/step - loss: 3.4764e-04 - lr: 0.0010
# Epoch 82/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 2.8033e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 15ms/step - loss: 2.8000e-04 - lr: 0.0010
# Epoch 83/100
# 1608/1608 [==============================] - ETA: 0s - loss: 2.7739e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 27s 17ms/step - loss: 2.7739e-04 - lr: 0.0010
# Epoch 84/100
# 1608/1608 [==============================] - ETA: 0s - loss: 2.8492e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 2.8492e-04 - lr: 0.0010
# Epoch 85/100
# 1608/1608 [==============================] - ETA: 0s - loss: 2.8936e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 2.8936e-04 - lr: 0.0010
# Epoch 86/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 0.0033WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 0.0033 - lr: 0.0010
# Epoch 87/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 7.5579e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 7.5468e-04 - lr: 0.0010
# Epoch 88/100
# 1608/1608 [==============================] - ETA: 0s - loss: 7.0964e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 15ms/step - loss: 7.0964e-04 - lr: 0.0010
# Epoch 89/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 6.8169e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 24s 15ms/step - loss: 6.8127e-04 - lr: 0.0010
# Epoch 90/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 4.9104e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 4.9074e-04 - lr: 0.0010
# Epoch 91/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 3.6635e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 24s 15ms/step - loss: 3.6595e-04 - lr: 0.0010
# Epoch 92/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 4.4125e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 24s 15ms/step - loss: 4.4071e-04 - lr: 0.0010
# Epoch 93/100
# 1608/1608 [==============================] - ETA: 0s - loss: 2.9129e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 2.9129e-04 - lr: 0.0010
# Epoch 94/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 5.5694e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 15ms/step - loss: 5.5660e-04 - lr: 0.0010
# Epoch 95/100
# 1608/1608 [==============================] - ETA: 0s - loss: 2.9679e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 2.9679e-04 - lr: 0.0010
# Epoch 96/100
# 1608/1608 [==============================] - ETA: 0s - loss: 5.6223e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 24s 15ms/step - loss: 5.6223e-04 - lr: 0.0010
# Epoch 97/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.4905e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 3.4905e-04 - lr: 0.0010
# Epoch 98/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 3.3515e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.3483e-04 - lr: 0.0010
# Epoch 99/100
# 1608/1608 [==============================] - ETA: 0s - loss: 3.7379e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 25s 16ms/step - loss: 3.7379e-04 - lr: 0.0010
# Epoch 100/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 3.2876e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 26s 16ms/step - loss: 3.2815e-04 - lr: 0.0010

# %%
loss_per_epoch = model.history.history['loss']

# %%
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_prediction = []
first_eval_batch = scaler_train[-12:]
current_batch = first_eval_batch.reshape((1,n_input,n_features))

for i in range(len(test)):
  current_pred = model.predict(current_batch)[0]
  test_prediction.append(current_pred)
  current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
true_prediction = scaler.inverse_transform(test_prediction)

# %%
true_prediction
# Out:
# array([[3.87838088],
#        [3.70798047],
#        [3.63107247],
#        [3.58828104],
#        [3.51676673],
#        [3.53251746],
#        [3.44502991],
#        [3.41893708],
#        [3.41567269],
#        [3.44989051],
#        [3.49929699],
#        [3.43856223],
#        [3.41834442],
#        [3.40401286],
#        [3.39181536],
#        [3.37775302],
#        [3.37084349],
#        [3.35664787],
#        [3.34737281],
#        [3.34218342],
#        [3.34098855],
#        [3.34306828],
#        [3.33619745],
#        [3.33114972],
#        [3.32697387],
#        [3.32321824],
#        [3.31947043],
#        [3.31648126],
#        [3.31310486],
#        [3.31024514],
#        [3.30805236],
#        [3.30643556],
#        [3.30540942],
#        [3.30380254],
#        [3.3023028 ],
#        [3.30095407],
#        [3.29972107],
#        [3.29855576],
#        [3.29751666],
#        [3.29650997],
#        [3.2955988 ],
#        [3.29481481],
#        [3.29414959],
#        [3.29364911],
#        [3.29321021],
#        [3.29281287],
#        [3.29245996],
#        [3.2921448 ],
#        [3.29186281],
#        [3.29160981],
#        [3.29138121],
#        [3.29117567],
#        [3.29099436],
#        [3.29083687],
#        [3.29070188],
#        [3.29058596],
#        [3.29048377],
#        [3.29039378],
#        [3.2903137 ],
#        [3.29024315],
#        [3.29018062],
#        [3.29012552],
#        [3.29007614],
#        [3.29003152],
#        [3.28999339],
#        [3.2899606 ],
#        [3.28993142],
#        [3.28990511],
#        [3.28988262],
#        [3.28986298],
#        [3.28984506],
#        [3.28983018],
#        [3.28981646],
#        [3.28980406],
#        [3.28979377],
#        [3.28978404],
#        [3.28977604],
#        [3.28976879],
#        [3.28976269],
#        [3.28975678],
#        [3.28975201],
#        [3.28974687],
#        [3.28974286],
#        [3.28974038],
#        [3.28973676],
#        [3.28973447],
#        [3.28973199],
#        [3.2897299 ],
#        [3.28972799],
#        [3.28972666],
#        [3.28972513],
#        [3.28972341],
#        [3.28972246],
#        [3.28972189],
#        [3.28972094],
#        [3.28971998],
#        [3.28971922],
#        [3.28971903],
#        [3.28971827],
#        [3.28971789],
#        [3.28971789],
#        [3.28971731],
#        [3.28971655],
#        [3.28971655],
#        [3.28971636],
#        [3.28971655],
#        [3.28971617],
#        [3.28971598],
#        [3.28971598],
#        [3.28971522],
#        [3.28971522],
#        [3.28971541],
#        [3.28971483],
#        [3.28971483],
#        [3.28971503],
#        [3.28971483],
#        [3.28971464],
#        [3.28971445],
#        [3.28971445],
#        [3.28971426],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971426],
#        [3.28971388],
#        [3.2897135 ],
#        [3.28971388],
#        [3.28971369],
#        [3.28971407],
#        [3.28971369],
#        [3.28971407],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971369],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971426],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388],
#        [3.28971369],
#        [3.28971369],
#        [3.28971388],
#        [3.28971388],
#        [3.28971388]])

# %%
test['prediction'] = true_prediction
# Out:
# C:\Users\fahamed\AppData\Local\Temp\ipykernel_8928\2961615516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction'] = true_prediction

# %%
test
# Out:
#                      CPU usage [%]  prediction
# Timestamp
# 2015-01-09 15:00:00           3.90    3.878381
# 2015-01-09 15:05:00           3.53    3.707980
# 2015-01-09 15:10:00           3.73    3.631072
# 2015-01-09 15:15:00           3.64    3.588281
# 2015-01-09 15:20:00           3.42    3.516767
# ...                            ...         ...
# 2015-01-10 23:40:00           3.35    3.289714
# 2015-01-10 23:45:00           3.44    3.289714
# 2015-01-10 23:50:00           3.30    3.289714
# 2015-01-10 23:55:00           3.51    3.289714
# 2015-01-11 00:00:00           3.32    3.289714
#
# [397 rows x 2 columns]

# %%
test.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test['CPU usage [%]'], test['prediction']))
print("RMSE:", rmse)
# Out:
# RMSE: 0.364866943462763

# %%
mse = mean_squared_error(test['CPU usage [%]'], test['prediction'])
print("MSE:", mse)
# Out:
# MSE: 0.13312788643185908

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(test['CPU usage [%]'], test['prediction'])
print("MAE:", mae)
# Out:
# MAE: 0.194181981280033
