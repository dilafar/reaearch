# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("./cpu_usage.csv", parse_dates=[0])
dataset.head(20)
# Out:
#              Timestamp  CPU cores  CPU capacity provisioned [MHZ]  \
# 0  2015-01-04 00:00:00          2                               0
# 1  2015-01-04 00:05:00          2                               0
# 2  2015-01-04 00:10:00          2                               0
# 3  2015-01-04 00:15:00          2                               0
# 4  2015-01-04 00:20:00          2                               0
# 5  2015-01-04 00:25:00          2                               0
# 6  2015-01-04 00:30:00          2                               0
# 7  2015-01-04 00:35:00          2                               0
# 8  2015-01-04 00:40:00          2                               0
# 9  2015-01-04 00:45:00          2                               0
# 10 2015-01-04 00:50:00          2                               0
# 11 2015-01-04 00:55:00          2                               0
# 12 2015-01-04 01:00:00          2                               0
# 13 2015-01-04 01:05:00          2                               0
# 14 2015-01-04 01:10:00          2                               0
# 15 2015-01-04 01:15:00          2                               0
# 16 2015-01-04 01:20:00          2                               0
# 17 2015-01-04 01:25:00          2                               0
# 18 2015-01-04 01:30:00          2                               0
# 19 2015-01-04 01:35:00          2                               0
#
#     CPU usage [MHZ]  CPU usage [%]  Memory capacity provisioned [KB]  \
# 0               156           3.40                           4194304
# 1               150           3.27                           4194304
# 2               158           3.46                           4194304
# 3               156           3.40                           4194304
# 4               159           3.47                           4194304
# 5               152           3.31                           4194304
# 6               149           3.25                           4194304
# 7               160           3.50                           4194304
# 8               156           3.40                           4194304
# 9               148           3.23                           4194304
# 10              169           3.69                           4194304
# 11              148           3.23                           4194304
# 12              150           3.28                           4194304
# 13              167           3.64                           4194304
# 14              148           3.23                           4194304
# 15              150           3.28                           4194304
# 16              157           3.42                           4194304
# 17              136           2.97                           4194304
# 18              141           3.08                           4194304
# 19              133           2.92                           4194304
#
#     Memory usage [KB]  Memory usage [%]  Disk read throughput [KB/s]  \
# 0             1050673             25.05                            0
# 1             1095552             26.12                            0
# 2             1025507             24.45                            0
# 3              992372             23.66                            0
# 4             1129107             26.92                            0
# 5             1092616             26.05                            0
# 6              958398             22.85                            0
# 7             1187827             28.32                            0
# 8             1101005             26.25                            0
# 9             1115265             26.59                            0
# 10            1241095             29.59                            0
# 11            1182374             28.19                            0
# 12            1053609             25.12                            0
# 13             941621             22.45                            0
# 14            1011666             24.12                            0
# 15             964270             22.99                            0
# 16             983564             23.45                            0
# 17             891290             21.25                            0
# 18             885837             21.12                            0
# 19             939105             22.39                            0
#
#     Disk write throughput [KB/s]  Disk size [GB]  \
# 0                             14              54
# 1                             17              54
# 2                             15              54
# 3                             16              54
# 4                             15              54
# 5                             15              54
# 6                             13              54
# 7                             72              54
# 8                             14              54
# 9                             15              54
# 10                            15              54
# 11                            16              54
# 12                            15              54
# 13                            16              54
# 14                            14              54
# 15                            15              54
# 16                            14              54
# 17                            16              54
# 18                            14              54
# 19                            15              54
#
#     Network received throughput [KB/s]  Network transmitted throughput [KB/s]
# 0                                   12                                     45
# 1                                    2                                     13
# 2                                   12                                     45
# 3                                    3                                     12
# 4                                   13                                     46
# 5                                    2                                     11
# 6                                    2                                     11
# 7                                    2                                     53
# 8                                   12                                     45
# 9                                    2                                     11
# 10                                  12                                     45
# 11                                   2                                     11
# 12                                   2                                     11
# 13                                 164                                     20
# 14                                   2                                     11
# 15                                   2                                     11
# 16                                  12                                     45
# 17                                   2                                     11
# 18                                  12                                     45
# 19                                   2                                     11

# %%
dataset = dataset.set_index('Timestamp').asfreq(freq='5min')

dataset.drop(columns=[
    'CPU cores',
    'CPU capacity provisioned [MHZ]',
    'CPU usage [MHZ]',
    'Memory capacity provisioned [KB]',
    'Memory usage [KB]',
    'Memory usage [%]',
    'Disk read throughput [KB/s]',
    'Disk write throughput [KB/s]',
    'Disk size [GB]',
    'Network received throughput [KB/s]',
    'Network transmitted throughput [KB/s]'
] , inplace=True)

# %%
dataset.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
dataset.columns[0]
# Out:
# 'CPU usage [%]'

# %%
train = dataset.iloc[:1620]
test = dataset.iloc[1620:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler_train = scaler.fit(train)
scaler_train = scaler.transform(train)
scaler_test = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
n_input =12
n_features = 1

generator = TimeseriesGenerator(scaler_train,scaler_train,length=n_input,batch_size=1)

# %%
len(generator)
# Out:
# 1608

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM , Conv1D ,MaxPooling1D
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.optimizers import Adam
#from keras.optimizers import clipnorm
from keras import regularizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau

# %%
from keras.layers import Input, Dense, LSTM, Conv1D, Dropout, Bidirectional, Multiply
from keras.models import Model
# from attention_utils import get_activations
from keras.models import *
from sklearn.model_selection import train_test_split

# %%
model = Sequential()

# %%
model.add(LSTM(64, return_sequences=False, activation='relu', input_shape=(n_input, n_features)))

# %%
model.add(Dense(units=16))
model.add(Dense(units=2))
model.add(Dense(units=1))
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(factor=0.5, patience=5, min_lr=1e-6)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                16896
#
#  dense_9 (Dense)             (None, 16)                1040
#
#  dense_10 (Dense)            (None, 2)                 34
#
#  dense_11 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 17973 (70.21 KB)
# Trainable params: 17973 (70.21 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(generator,epochs=100,batch_size=32, callbacks=[early_stopping,lr_scheduler])
# Out:
# Epoch 1/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 0.0011WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 21s 9ms/step - loss: 0.0011 - lr: 0.0010
# Epoch 2/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 0.0011WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 0.0011 - lr: 0.0010
# Epoch 3/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 4/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 5/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 6/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 7/100
# 1608/1608 [==============================] - ETA: 0s - loss: 0.0010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 8/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.6767e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 10ms/step - loss: 9.6586e-04 - lr: 0.0010
# Epoch 9/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.9290e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.9229e-04 - lr: 0.0010
# Epoch 10/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.7562e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.7502e-04 - lr: 0.0010
# Epoch 11/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.8168e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.8107e-04 - lr: 0.0010
# Epoch 12/100
# 1602/1608 [============================>.] - ETA: 0s - loss: 9.6912e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 9.6567e-04 - lr: 0.0010
# Epoch 13/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.6293e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.6056e-04 - lr: 0.0010
# Epoch 14/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.6265e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.5986e-04 - lr: 0.0010
# Epoch 15/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.7058e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.6939e-04 - lr: 0.0010
# Epoch 16/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.4368e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.4315e-04 - lr: 0.0010
# Epoch 17/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.4819e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 11ms/step - loss: 9.4791e-04 - lr: 0.0010
# Epoch 18/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.8394e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.8158e-04 - lr: 0.0010
# Epoch 19/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.5063e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.4862e-04 - lr: 0.0010
# Epoch 20/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.6085e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.6031e-04 - lr: 0.0010
# Epoch 21/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.5797e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.5738e-04 - lr: 0.0010
# Epoch 22/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.5396e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.5337e-04 - lr: 0.0010
# Epoch 23/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.5220e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.4926e-04 - lr: 0.0010
# Epoch 24/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.4952e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.4910e-04 - lr: 0.0010
# Epoch 25/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.5182e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 9.4948e-04 - lr: 0.0010
# Epoch 26/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.3355e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.3240e-04 - lr: 0.0010
# Epoch 27/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.4237e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 9.4011e-04 - lr: 0.0010
# Epoch 28/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.3932e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 9.3874e-04 - lr: 0.0010
# Epoch 29/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.4243e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.4080e-04 - lr: 0.0010
# Epoch 30/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.3828e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.3713e-04 - lr: 0.0010
# Epoch 31/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.2712e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.2599e-04 - lr: 0.0010
# Epoch 32/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.3610e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.3402e-04 - lr: 0.0010
# Epoch 33/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.3448e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.3448e-04 - lr: 0.0010
# Epoch 34/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.2707e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.2543e-04 - lr: 0.0010
# Epoch 35/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.3893e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.4089e-04 - lr: 0.0010
# Epoch 36/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.2647e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 10ms/step - loss: 9.2533e-04 - lr: 0.0010
# Epoch 37/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.2233e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 10ms/step - loss: 9.2177e-04 - lr: 0.0010
# Epoch 38/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.2972e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 9.2685e-04 - lr: 0.0010
# Epoch 39/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.2165e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 9.1995e-04 - lr: 0.0010
# Epoch 40/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.2833e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 11ms/step - loss: 9.2558e-04 - lr: 0.0010
# Epoch 41/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.3744e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.3516e-04 - lr: 0.0010
# Epoch 42/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.0891e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 18s 11ms/step - loss: 9.0666e-04 - lr: 0.0010
# Epoch 43/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.9706e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.9551e-04 - lr: 0.0010
# Epoch 44/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.2279e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 18s 11ms/step - loss: 9.2222e-04 - lr: 0.0010
# Epoch 45/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.8570e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 20s 13ms/step - loss: 8.8570e-04 - lr: 0.0010
# Epoch 46/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.2721e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.2500e-04 - lr: 0.0010
# Epoch 47/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.2541e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.2316e-04 - lr: 0.0010
# Epoch 48/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.0228e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.0013e-04 - lr: 0.0010
# Epoch 49/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.8967e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 18s 11ms/step - loss: 8.8752e-04 - lr: 0.0010
# Epoch 50/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.2044e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.1761e-04 - lr: 0.0010
# Epoch 51/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.8377e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.8271e-04 - lr: 0.0010
# Epoch 52/100
# 1602/1608 [============================>.] - ETA: 0s - loss: 9.0856e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 13s 8ms/step - loss: 9.0569e-04 - lr: 0.0010
# Epoch 53/100
# 1608/1608 [==============================] - ETA: 0s - loss: 9.3286e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.3286e-04 - lr: 0.0010
# Epoch 54/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.7583e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.7583e-04 - lr: 0.0010
# Epoch 55/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.1213e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.1100e-04 - lr: 0.0010
# Epoch 56/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.6354e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.6152e-04 - lr: 0.0010
# Epoch 57/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.2643e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.2436e-04 - lr: 0.0010
# Epoch 58/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.1096e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.1040e-04 - lr: 0.0010
# Epoch 59/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.8845e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.8789e-04 - lr: 0.0010
# Epoch 60/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 8.7467e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.7316e-04 - lr: 0.0010
# Epoch 61/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 8.6318e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 8.6159e-04 - lr: 0.0010
# Epoch 62/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 9.1976e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.1697e-04 - lr: 0.0010
# Epoch 63/100
# 1602/1608 [============================>.] - ETA: 0s - loss: 8.5937e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.5633e-04 - lr: 0.0010
# Epoch 64/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.5788e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 8.5788e-04 - lr: 0.0010
# Epoch 65/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 9.3201e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.3185e-04 - lr: 0.0010
# Epoch 66/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.4018e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 10ms/step - loss: 8.3823e-04 - lr: 0.0010
# Epoch 67/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.8925e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.8871e-04 - lr: 0.0010
# Epoch 68/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 8.5149e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.4991e-04 - lr: 0.0010
# Epoch 69/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 8.7408e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.7256e-04 - lr: 0.0010
# Epoch 70/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.0539e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 8.4410e-04 - lr: 0.0010
# Epoch 71/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.8218e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.8163e-04 - lr: 0.0010
# Epoch 72/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 8.4782e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 8.4579e-04 - lr: 0.0010
# Epoch 73/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 8.5915e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.5759e-04 - lr: 0.0010
# Epoch 74/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.7842e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 8.7734e-04 - lr: 0.0010
# Epoch 75/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 8.2408e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 8ms/step - loss: 8.2229e-04 - lr: 0.0010
# Epoch 76/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.3664e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.3435e-04 - lr: 0.0010
# Epoch 77/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.2897e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 10ms/step - loss: 8.2710e-04 - lr: 0.0010
# Epoch 78/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 9.1427e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 17s 10ms/step - loss: 9.1216e-04 - lr: 0.0010
# Epoch 79/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.7922e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.7742e-04 - lr: 0.0010
# Epoch 80/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.3777e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 8.3726e-04 - lr: 0.0010
# Epoch 81/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.2404e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.2372e-04 - lr: 0.0010
# Epoch 82/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 8.6796e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.6536e-04 - lr: 0.0010
# Epoch 83/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 7.1958e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 7.9198e-04 - lr: 0.0010
# Epoch 84/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.2013e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.2013e-04 - lr: 0.0010
# Epoch 85/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.1889e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 9.1763e-04 - lr: 0.0010
# Epoch 86/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.1836e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.1737e-04 - lr: 0.0010
# Epoch 87/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 7.8769e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 12s 7ms/step - loss: 7.8681e-04 - lr: 0.0010
# Epoch 88/100
# 1606/1608 [============================>.] - ETA: 0s - loss: 8.1907e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 13s 8ms/step - loss: 8.1965e-04 - lr: 0.0010
# Epoch 89/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 8.5386e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 13s 8ms/step - loss: 8.5147e-04 - lr: 0.0010
# Epoch 90/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.7535e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.7325e-04 - lr: 0.0010
# Epoch 91/100
# 1602/1608 [============================>.] - ETA: 0s - loss: 8.1266e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 16s 10ms/step - loss: 8.0991e-04 - lr: 0.0010
# Epoch 92/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.5043e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 8.4990e-04 - lr: 0.0010
# Epoch 93/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 9.9850e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 9.9689e-04 - lr: 0.0010
# Epoch 94/100
# 1604/1608 [============================>.] - ETA: 0s - loss: 8.5757e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 8.5546e-04 - lr: 0.0010
# Epoch 95/100
# 1605/1608 [============================>.] - ETA: 0s - loss: 8.9547e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 13s 8ms/step - loss: 8.9383e-04 - lr: 0.0010
# Epoch 96/100
# 1603/1608 [============================>.] - ETA: 0s - loss: 8.9544e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 13s 8ms/step - loss: 8.9282e-04 - lr: 0.0010
# Epoch 97/100
# 1601/1608 [============================>.] - ETA: 0s - loss: 8.6129e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 13s 8ms/step - loss: 8.5769e-04 - lr: 0.0010
# Epoch 98/100
# 1608/1608 [==============================] - ETA: 0s - loss: 8.8988e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 14s 9ms/step - loss: 8.8988e-04 - lr: 0.0010
# Epoch 99/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 8.5110e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 10ms/step - loss: 8.5057e-04 - lr: 0.0010
# Epoch 100/100
# 1607/1608 [============================>.] - ETA: 0s - loss: 9.0176e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 1608/1608 [==============================] - 15s 9ms/step - loss: 9.0147e-04 - lr: 0.0010

# %%
loss_per_epoch = model.history.history['loss']

# %%
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_prediction = []
first_eval_batch = scaler_train[-12:]
current_batch = first_eval_batch.reshape((1,n_input,n_features))

for i in range(len(test)):
  current_pred = model.predict(current_batch)[0]
  test_prediction.append(current_pred)
  current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
true_prediction = scaler.inverse_transform(test_prediction)

# %%
true_prediction
# Out:
# array([[3.81646498],
#        [3.56964981],
#        [3.4541409 ],
#        [3.38185965],
#        [3.32146798],
#        [3.25841355],
#        [3.21715236],
#        [3.17459163],
#        [3.13379298],
#        [3.08006985],
#        [3.02266164],
#        [2.97271778],
#        [2.92843843],
#        [2.88859614],
#        [2.85184712],
#        [2.81754732],
#        [2.78540427],
#        [2.75483837],
#        [2.72585875],
#        [2.69837316],
#        [2.67264774],
#        [2.64871948],
#        [2.62639506],
#        [2.60552309],
#        [2.58597544],
#        [2.56765489],
#        [2.55047982],
#        [2.53437703],
#        [2.5192958 ],
#        [2.50517625],
#        [2.49196502],
#        [2.47960527],
#        [2.46803943],
#        [2.45721412],
#        [2.44708014],
#        [2.43740603],
#        [2.42804842],
#        [2.41914191],
#        [2.41070595],
#        [2.40272148],
#        [2.3951679 ],
#        [2.38801966],
#        [2.38124931],
#        [2.37483778],
#        [2.36876067],
#        [2.36300082],
#        [2.35754069],
#        [2.35236808],
#        [2.34746696],
#        [2.34282095],
#        [2.33842051],
#        [2.33425077],
#        [2.33030295],
#        [2.32656334],
#        [2.32301973],
#        [2.31966334],
#        [2.31648427],
#        [2.3134726 ],
#        [2.31061956],
#        [2.307916  ],
#        [2.30535581],
#        [2.30293061],
#        [2.30063353],
#        [2.29845772],
#        [2.2963963 ],
#        [2.29444317],
#        [2.29259301],
#        [2.29084274],
#        [2.289184  ],
#        [2.28761143],
#        [2.28612276],
#        [2.28471187],
#        [2.28337496],
#        [2.2821105 ],
#        [2.28090934],
#        [2.27977453],
#        [2.27869997],
#        [2.2776826 ],
#        [2.27671939],
#        [2.27580498],
#        [2.27493938],
#        [2.27411878],
#        [2.2733447 ],
#        [2.27260799],
#        [2.27191322],
#        [2.27125277],
#        [2.27062817],
#        [2.27003483],
#        [2.26947353],
#        [2.26894426],
#        [2.26844015],
#        [2.2679635 ],
#        [2.26751202],
#        [2.26708417],
#        [2.26667921],
#        [2.26629484],
#        [2.26593259],
#        [2.2655894 ],
#        [2.26526299],
#        [2.26495412],
#        [2.26466126],
#        [2.26438442],
#        [2.26412284],
#        [2.2638765 ],
#        [2.26364009],
#        [2.26341587],
#        [2.26320691],
#        [2.26300633],
#        [2.26281643],
#        [2.26263645],
#        [2.26246638],
#        [2.26230851],
#        [2.26215522],
#        [2.26201032],
#        [2.26187381],
#        [2.26174492],
#        [2.26161985],
#        [2.26150469],
#        [2.26139487],
#        [2.26128963],
#        [2.26119277],
#        [2.2610982 ],
#        [2.26100974],
#        [2.26092737],
#        [2.26084806],
#        [2.26077179],
#        [2.26069934],
#        [2.26063299],
#        [2.26057045],
#        [2.26050944],
#        [2.26045148],
#        [2.26039733],
#        [2.26034548],
#        [2.26029743],
#        [2.26025243],
#        [2.2602082 ],
#        [2.26016473],
#        [2.26012507],
#        [2.26008923],
#        [2.26005338],
#        [2.26002059],
#        [2.25998932],
#        [2.25996034],
#        [2.25993136],
#        [2.25990314],
#        [2.25988103],
#        [2.25985662],
#        [2.25983298],
#        [2.2598101 ],
#        [2.25979027],
#        [2.25976968],
#        [2.25975061],
#        [2.2597346 ],
#        [2.25971782],
#        [2.25970257],
#        [2.25968808],
#        [2.25967435],
#        [2.25965986],
#        [2.2596469 ],
#        [2.25963469],
#        [2.25962325],
#        [2.25961258],
#        [2.25959961],
#        [2.25959275],
#        [2.25958512],
#        [2.25957673],
#        [2.25956758],
#        [2.25955919],
#        [2.25955233],
#        [2.25954546],
#        [2.25953708],
#        [2.25953021],
#        [2.25952716],
#        [2.2595203 ],
#        [2.25951496],
#        [2.25951115],
#        [2.25950657],
#        [2.25950199],
#        [2.25949742],
#        [2.25949513],
#        [2.25949055],
#        [2.2594875 ],
#        [2.25948598],
#        [2.2594814 ],
#        [2.25947759],
#        [2.25947378],
#        [2.25947149],
#        [2.25946844],
#        [2.25946615],
#        [2.25946462],
#        [2.25946081],
#        [2.25945929],
#        [2.25945776],
#        [2.25945547],
#        [2.25945395],
#        [2.25945242],
#        [2.25944937],
#        [2.25944785],
#        [2.25944708],
#        [2.25944708],
#        [2.2594448 ],
#        [2.25944403],
#        [2.25944174],
#        [2.25944098],
#        [2.25944098],
#        [2.25943946],
#        [2.25943946],
#        [2.25943946],
#        [2.25943793],
#        [2.25943641],
#        [2.25943641],
#        [2.25943564],
#        [2.25943488],
#        [2.25943488],
#        [2.25943488],
#        [2.25943183],
#        [2.25943107],
#        [2.25943107],
#        [2.25943031],
#        [2.25942954],
#        [2.25942878],
#        [2.25942878],
#        [2.25942954],
#        [2.25942878],
#        [2.25942878],
#        [2.25942878],
#        [2.25942878],
#        [2.2594242 ],
#        [2.25942573],
#        [2.25942649],
#        [2.25942878],
#        [2.25942878],
#        [2.2594242 ],
#        [2.25942497],
#        [2.25942573],
#        [2.25942573],
#        [2.25942573],
#        [2.2594242 ],
#        [2.2594242 ],
#        [2.2594242 ],
#        [2.2594242 ],
#        [2.2594242 ],
#        [2.2594242 ],
#        [2.2594242 ],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344],
#        [2.25942344]])

# %%
test['prediction'] = true_prediction
# Out:
# C:\Users\fahamed\AppData\Local\Temp\ipykernel_19244\2961615516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction'] = true_prediction

# %%
test
# Out:
#                      CPU usage [%]  prediction
# Timestamp
# 2015-01-09 15:00:00           3.90    3.816465
# 2015-01-09 15:05:00           3.53    3.569650
# 2015-01-09 15:10:00           3.73    3.454141
# 2015-01-09 15:15:00           3.64    3.381860
# 2015-01-09 15:20:00           3.42    3.321468
# ...                            ...         ...
# 2015-01-10 23:40:00           3.35    2.259423
# 2015-01-10 23:45:00           3.44    2.259423
# 2015-01-10 23:50:00           3.30    2.259423
# 2015-01-10 23:55:00           3.51    2.259423
# 2015-01-11 00:00:00           3.32    2.259423
#
# [397 rows x 2 columns]

# %%
test.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test['CPU usage [%]'], test['prediction']))
print("RMSE:", rmse)
# Out:
# RMSE: 1.2144278099337076

# %%
mse = mean_squared_error(test['CPU usage [%]'], test['prediction'])
print("MSE:", mse)
# Out:
# MSE: 1.4748349055403815

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(test['CPU usage [%]'], test['prediction'])
print("MAE:", mae)
# Out:
# MAE: 1.160831789017024
